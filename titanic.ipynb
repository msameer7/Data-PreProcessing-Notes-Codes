# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.offline import init_notebook_mode
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('titanic.csv')
# Out:
#      <input type="file" id="files-a79995b2-e555-40bb-b8ad-50cb6a98e3fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a79995b2-e555-40bb-b8ad-50cb6a98e3fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic (15).csv

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN     NaN   NaN    NaN    NaN
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309     NaN      NaN   NaN      NaN  NaN    NaN       NaN

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.shape
# Out:
# (1310, 14)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.select_dtypes(exclude = 'int64')
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
df.isnull().sum().sum()
# Out:
# 3869

# %%
df.isna().sum(axis = 0)
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
df.drop(["body","boat", "home.dest", "cabin"],axis=1, inplace = True)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare embarked
# 0  29.0000    0.0    0.0   24160  211.3375        S
# 1   0.9167    1.0    2.0  113781  151.5500        S
# 2   2.0000    1.0    2.0  113781  151.5500        S
# 3  30.0000    1.0    2.0  113781  151.5500        S
# 4  25.0000    1.0    2.0  113781  151.5500        S

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN     NaN   NaN    NaN    NaN
#
#       ticket     fare embarked
# 1305    2665  14.4542        C
# 1306    2656   7.2250        C
# 1307    2670   7.2250        C
# 1308  315082   7.8750        S
# 1309     NaN      NaN      NaN

# %%
df.isna().sum(axis = 0)
# Out:
# pclass        1
# survived      1
# name          1
# sex           1
# age         264
# sibsp         1
# parch         1
# ticket        1
# fare          2
# embarked      3
# dtype: int64

# %%
df['pclass'].fillna(3.0, inplace = True)

# %%
df['sex'].fillna('male', inplace = True)

# %%
df['survived'].fillna('0', inplace = True)

# %%
df['age'].fillna('30', inplace = True)

# %%
df['fare'].fillna('876', inplace = True)

# %%
df['ticket'].fillna('23412', inplace = True)

# %%
df['embarked'].fillna('S', inplace = True)

# %%
df.drop('sibsp', inplace=True, axis=1)

# %%
df.drop('parch', inplace=True, axis=1)

# %%
df.drop('name', inplace=True, axis=1)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    pclass survived     sex     age  ticket      fare embarked
# 0     1.0      1.0  female    29.0   24160  211.3375        S
# 1     1.0      1.0    male  0.9167  113781    151.55        S
# 2     1.0      0.0  female     2.0  113781    151.55        S
# 3     1.0      0.0    male    30.0  113781    151.55        S
# 4     1.0      0.0  female    25.0  113781    151.55        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['ticket'] = le.fit_transform(df.ticket)

# %%
df['sex'] = le.fit_transform(df.sex)

# %%
df['embarked'] = le.fit_transform(df.embarked)

# %%
df['age'] = df['age'].astype(int)

# %%
df['survived'] = df['survived'].astype(int)

# %%
df['fare'] = df['fare'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1310 non-null   float64
#  1   survived  1310 non-null   int64
#  2   sex       1310 non-null   int64
#  3   age       1310 non-null   int64
#  4   ticket    1310 non-null   int64
#  5   fare      1310 non-null   int64
#  6   embarked  1310 non-null   int64
# dtypes: float64(1), int64(6)
# memory usage: 71.8 KB

# %%
df.head()
# Out:
#    pclass  survived  sex  age  ticket  fare  embarked
# 0     1.0         1    0   29     188   211         2
# 1     1.0         1    1    0      49   151         2
# 2     1.0         0    0    2      49   151         2
# 3     1.0         0    1   30      49   151         2
# 4     1.0         0    0   25      49   151         2

# %%
sns.catplot(x="sex", y="survived", data=df)

# %%
columns=['survived', 'female', 'male',] 
values = [706, 108, 128,]
fig = go.Figure(data=[go.Pie(labels=columns,
                      values=values)])
  
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
